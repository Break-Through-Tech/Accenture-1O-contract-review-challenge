# %% [markdown]
# # Task #6: Create the Five Review Bundles
#
# Takes the final 10 categories from Task #5 and pairs them into **exactly 5 bundles of exactly 2**, each with a documented rationale and the
# strongest alternative pairing that wasn't chosen -- the two things Task #6 requires.
#
# This notebook computes *real* co-occurrence numbers for all 45 possible pairs among the 10 (from Task #3 data), so the pairing decisions are grounded in actual numbers instead of guesses.

# %%
import re
import pandas as pd
from itertools import combinations
from pathlib import Path
import json

# %% [markdown]
# ## Load Task #3's data + the final 10 categories

# %%
DATA_DIR = Path("task3_outputs")
OUTPUT_DIR = Path("task6_outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

category_cooccurrence = pd.read_csv(DATA_DIR / "category_cooccurrence.csv", index_col=0)

# the final 10 from Task #5 (Maya's Step 9) -- edit this if the team's final list differs
final_10 = [
    "Governing Law",
    "Renewal Term",
    "Revenue/Profit Sharing",
    "Cap On Liability",
    "Uncapped Liability",
    "Termination For Convenience",
    "Anti-Assignment",
    "Audit Rights",
    "License Grant",
    "Exclusivity",
]

assert len(final_10) == 10, f"expected 10 categories, got {len(final_10)}"
print(f"{len(final_10)} categories loaded")
# Out:
# 10 categories loaded

# %%
print(category_cooccurrence.index.tolist())
# Out:
# ['document_name', 'parties', 'agreement_date', 'effective_date', 'expiration_date', 'renewal_term', 'notice_period_to_terminate_renewal', 'governing_law', 'most_favored_nation', 'non_compete', 'exclusivity', 'no_solicit_of_customers', 'competitive_restriction_exception', 'no_solicit_of_employees', 'non_disparagement', 'termination_for_convenience', 'rofr_rofo_rofn', 'change_of_control', 'anti_assignment', 'revenue_profit_sharing', 'price_restrictions', 'minimum_commitment', 'volume_restriction', 'ip_ownership_assignment', 'joint_ip_ownership', 'license_grant', 'non_transferable_license', 'affiliate_license_licensor', 'affiliate_license_licensee', 'unlimited_all_you_can_eat_license', 'irrevocable_or_perpetual_license', 'source_code_escrow', 'post_termination_services', 'audit_rights', 'uncapped_liability', 'cap_on_liability', 'liquidated_damages', 'warranty_duration', 'insurance', 'covenant_not_to_sue', 'third_party_beneficiary']

# %%
def to_snake_case(text):
    # Convert non-alphanumeric characters (spaces, slashes, hyphens) to a single underscore
    return re.sub(r'[^a-zA-Z0-9]+', '_', str(text)).strip('_').lower()

# Map snake_case versions -> exact index string in matrix
matrix_names = {to_snake_case(name): name for name in category_cooccurrence.index}

resolved = {}
for name in final_10:
    key = to_snake_case(name)
    if key in matrix_names:
        resolved[name] = matrix_names[key]
    else:
        print(f"WARNING -- '{name}' not found in category_cooccurrence.csv -- check spelling")

pair_rows = []
for a, b in combinations(final_10, 2):
    if a in resolved and b in resolved:
        count = category_cooccurrence.loc[resolved[a], resolved[b]]
        pair_rows.append({"category_a": a, "category_b": b, "cooccurrence_count": int(count)})

if pair_rows:
    pair_strength = pd.DataFrame(pair_rows).sort_values("cooccurrence_count", ascending=False).reset_index(drop=True)
else:
    pair_strength = pd.DataFrame(columns=["category_a", "category_b", "cooccurrence_count"])

pair_strength.to_csv(OUTPUT_DIR / "pair_strength_all_45.csv", index=False)
pair_strength
# Out:
#                      category_a                   category_b  \
# 0                 Governing Law              Anti-Assignment
# 1                 Governing Law             Cap On Liability
# 2              Cap On Liability              Anti-Assignment
# 3                 Governing Law                License Grant
# 4               Anti-Assignment                License Grant
# 5                 Governing Law                 Audit Rights
# 6               Anti-Assignment                 Audit Rights
# 7              Cap On Liability                License Grant
# 8                 Governing Law  Termination For Convenience
# 9                 Governing Law                 Renewal Term
# 10                Governing Law                  Exclusivity
# 11             Cap On Liability                 Audit Rights
# 12                 Renewal Term              Anti-Assignment
# 13  Termination For Convenience              Anti-Assignment
# 14              Anti-Assignment                  Exclusivity
# 15                 Audit Rights                License Grant
# 16                Governing Law       Revenue/Profit Sharing
# 17                 Renewal Term             Cap On Liability
# 18                License Grant                  Exclusivity
# 19             Cap On Liability  Termination For Convenience
# 20             Cap On Liability                  Exclusivity
# 21       Revenue/Profit Sharing              Anti-Assignment
# 22             Cap On Liability           Uncapped Liability
# 23           Uncapped Liability              Anti-Assignment
# 24                Governing Law           Uncapped Liability
# 25                 Renewal Term                License Grant
# 26                 Renewal Term                 Audit Rights
# 27       Revenue/Profit Sharing                License Grant
# 28                 Audit Rights                  Exclusivity
# 29       Revenue/Profit Sharing             Cap On Liability
# 30  Termination For Convenience                License Grant
# 31  Termination For Convenience                 Audit Rights
# 32       Revenue/Profit Sharing                 Audit Rights
# 33           Uncapped Liability                License Grant
# 34                 Renewal Term                  Exclusivity
# 35       Revenue/Profit Sharing                  Exclusivity
# 36                 Renewal Term       Revenue/Profit Sharing
# 37           Uncapped Liability                 Audit Rights
# 38                 Renewal Term  Termination For Convenience
# 39                 Renewal Term           Uncapped Liability
# 40       Revenue/Profit Sharing  Termination For Convenience
# 41  Termination For Convenience                  Exclusivity
# 42           Uncapped Liability                  Exclusivity
# 43           Uncapped Liability  Termination For Convenience
# 44       Revenue/Profit Sharing           Uncapped Liability
#
#     cooccurrence_count
# 0                  229
# 1                  180
# 2                  164
# 3                  155
# 4                  146
# 5                  137
# 6                  129
# 7                  124
# 8                  117
# 9                  114
# 10                 113
# 11                 113
# 12                 107
# 13                 104
# 14                 102
# 15                  94
# 16                  94
# 17                  91
# 18                  91
# 19                  90
# 20                  83
# 21                  81
# 22                  78
# 23                  77
# 24                  77
# 25                  77
# 26                  75
# 27                  72
# 28                  70
# 29                  70
# 30                  68
# 31                  67
# 32                  67
# 33                  64
# 34                  60
# 35                  58
# 36                  55
# 37                  55
# 38                  52
# 39                  42
# 40                  40
# 41                  40
# 42                  38
# 43                  33
# 44                  28

# %% [markdown]
# ## Proposed starting bundles

# %%
proposed_bundles = [
    {
        "bundle": 1, "category_a": "Cap On Liability", "category_b": "Uncapped Liability",
        "rationale": "Mutually exclusive liability structures -- a reviewer needs to know which one applies, so reviewing them together directly answers 'what's our risk exposure here?'",
        "alternative_considered": "Cap On Liability + Audit Rights",
        "alternative_reason": "Considered pairing liability exposure with the mechanism to monitor for breaches, but the direct cap-vs-uncapped contrast was judged more immediately useful to a reviewer.",
    },
    {
        "bundle": 2, "category_a": "License Grant", "category_b": "Exclusivity",
        "rationale": "Both define the scope of what's being licensed -- License Grant states what rights exist, Exclusivity states whether anyone else can also have them.",
        "alternative_considered": "License Grant + Anti-Assignment",
        "alternative_reason": "Considered pairing on 'what rights exist and whether they can move,' but Exclusivity ties more directly to the license's actual scope.",
    },
    {
        "bundle": 3, "category_a": "Renewal Term", "category_b": "Termination For Convenience",
        "rationale": "Contract lifecycle bookends -- how the agreement continues vs. how either party can end it early.",
        "alternative_considered": "Renewal Term + Governing Law",
        "alternative_reason": "Both are 'structural' clauses, but pairing renewal with termination is more directly actionable for a reviewer assessing contract flexibility.",
    },
    {
        "bundle": 4, "category_a": "Revenue/Profit Sharing", "category_b": "Audit Rights",
        "rationale": "Audit Rights are often the specific mechanism used to verify compliance with revenue/profit-sharing terms -- reviewing them together checks both the obligation and how it's enforced.",
        "alternative_considered": "Revenue/Profit Sharing + Exclusivity",
        "alternative_reason": "Exclusivity deals can have revenue implications, but Audit Rights connects more mechanically to verifying the revenue terms themselves.",
    },
    {
        "bundle": 5, "category_a": "Governing Law", "category_b": "Anti-Assignment",
        "rationale": "Both are structural/enforceability terms -- which jurisdiction's law applies, and whether contractual rights can be transferred under it.",
        "alternative_considered": "Governing Law + Renewal Term",
        "alternative_reason": "Both are administrative clauses, but Anti-Assignment pairs more naturally with Governing Law's enforceability angle than with renewal timing.",
    },
]

bundles_df = pd.DataFrame(proposed_bundles)

# attach the real co-occurrence count for each chosen pair, for reference
bundles_df = bundles_df.merge(
    pair_strength[["category_a", "category_b", "cooccurrence_count"]],
    on=["category_a", "category_b"], how="left"
)

bundles_df.to_csv(OUTPUT_DIR / "proposed_bundles.csv", index=False)
bundles_df
# Out:
#    bundle              category_a                   category_b  \
# 0       1        Cap On Liability           Uncapped Liability
# 1       2           License Grant                  Exclusivity
# 2       3            Renewal Term  Termination For Convenience
# 3       4  Revenue/Profit Sharing                 Audit Rights
# 4       5           Governing Law              Anti-Assignment
#
#                                            rationale  \
# 0  Mutually exclusive liability structures -- a r...
# 1  Both define the scope of what's being licensed...
# 2  Contract lifecycle bookends -- how the agreeme...
# 3  Audit Rights are often the specific mechanism ...
# 4  Both are structural/enforceability terms -- wh...
#
#                  alternative_considered  \
# 0       Cap On Liability + Audit Rights
# 1       License Grant + Anti-Assignment
# 2          Renewal Term + Governing Law
# 3  Revenue/Profit Sharing + Exclusivity
# 4          Governing Law + Renewal Term
#
#                                   alternative_reason  cooccurrence_count
# 0  Considered pairing liability exposure with the...                  78
# 1  Considered pairing on 'what rights exist and w...                  91
# 2  Both are 'structural' clauses, but pairing ren...                  52
# 3  Exclusivity deals can have revenue implication...                  67
# 4  Both are administrative clauses, but Anti-Assi...                 229

# %% [markdown]
# ## Checks

# %%
errors = []

if len(bundles_df) != 5:
    errors.append(f"expected 5 bundles, found {len(bundles_df)}")

all_categories_used = list(bundles_df["category_a"]) + list(bundles_df["category_b"])
if len(all_categories_used) != len(set(all_categories_used)):
    dupes = [c for c in set(all_categories_used) if all_categories_used.count(c) > 1]
    errors.append(f"category used in more than one bundle: {dupes}")

missing = set(final_10) - set(all_categories_used)
if missing:
    errors.append(f"category from the final 10 never appears in a bundle: {missing}")

extra = set(all_categories_used) - set(final_10)
if extra:
    errors.append(f"category in a bundle that isn't in the final 10: {extra}")

if errors:
    print("FAILED:")
    for e in errors:
        print(f"  - {e}")
else:
    print("PASSED -- 5 bundles, 2 categories each, all 10 categories covered exactly once.")
# Out:
# PASSED -- 5 bundles, 2 categories each, all 10 categories covered exactly once.

# %% [markdown]
# ## Summary

# %%
task6_summary = {
    "num_bundles": len(bundles_df),
    "categories_covered": sorted(all_categories_used),
    "checks_passed": len(errors) == 0,
}

with open(OUTPUT_DIR / "task6_summary.json", "w") as f:
    json.dump(task6_summary, f, indent=2)

task6_summary
# Out:
# {'num_bundles': 5,
#  'categories_covered': ['Anti-Assignment',
#   'Audit Rights',
#   'Cap On Liability',
#   'Exclusivity',
#   'Governing Law',
#   'License Grant',
#   'Renewal Term',
#   'Revenue/Profit Sharing',
#   'Termination For Convenience',
#   'Uncapped Liability'],
#  'checks_passed': True}
